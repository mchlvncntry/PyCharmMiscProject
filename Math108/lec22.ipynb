# %%
from datascience import *
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %%
botox = Table().with_columns('Group', make_array('Control', 'Treatment', 'Treatment','Control','Treatment','Treatment','Control'), 'Result', make_array(1,0,1,0,1,1,1))

# %%
botox
# Out:
# Group     | Result
# Control   | 1
# Treatment | 0
# Treatment | 1
# Control   | 0
# Treatment | 1
# Treatment | 1
# Control   | 1

# %%
botox.pivot('Group', 'Result') # "Group' array (control, treatment) becomes column labels
# Out:
# Result | Control | Treatment
# 0      | 1       | 1
# 1      | 2       | 3
